# %%
import torch
from google.colab import drive

# %%
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from torchvision import datasets

# %%
cifar = datasets.CIFAR10('/gdrive/MyDrive/Colab Notebooks/Pytorch/Datasets', download=True)
# Out:
# ...
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /gdrive/MyDrive/Colab Notebooks/Pytorch/Datasets/cifar-10-python.tar.gz to /gdrive/MyDrive/Colab Notebooks/Pytorch/Datasets

# %%
data = torch.Tensor(cifar.data)

# %%
data.size()
# Out:
# torch.Size([50000, 32, 32, 3])

# %%
data
# Out:
# tensor([[[[ 59.,  62.,  63.],
#           [ 43.,  46.,  45.],
#           [ 50.,  48.,  43.],
#           ...,
#           [158., 132., 108.],
#           [152., 125., 102.],
#           [148., 124., 103.]],
#
#          [[ 16.,  20.,  20.],
#           [  0.,   0.,   0.],
#           [ 18.,   8.,   0.],
#           ...,
#           [123.,  88.,  55.],
#           [119.,  83.,  50.],
#           [122.,  87.,  57.]],
#
#          [[ 25.,  24.,  21.],
#           [ 16.,   7.,   0.],
#           [ 49.,  27.,   8.],
#           ...,
#           [118.,  84.,  50.],
#           [120.,  84.,  50.],
#           [109.,  73.,  42.]],
#
#          ...,
#
#          [[208., 170.,  96.],
#           [201., 153.,  34.],
#           [198., 161.,  26.],
#           ...,
#           [160., 133.,  70.],
#           [ 56.,  31.,   7.],
#           [ 53.,  34.,  20.]],
#
#          [[180., 139.,  96.],
#           [173., 123.,  42.],
#           [186., 144.,  30.],
#           ...,
# ...
